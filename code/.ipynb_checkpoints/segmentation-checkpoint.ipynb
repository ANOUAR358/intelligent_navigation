# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
import os
import numpy as np 
import pandas as pd 
import imageio

import matplotlib.pyplot as plt

# %%
from data import *
from detector import *

# %%
#load data 
images_path=r"D:\project zone\intelligent_navigation\data\Files\CameraRGB"
masks_path=r"D:\project zone\intelligent_navigation\data\Files\CameraMask"
images_list,masks_list,dataset=load(images_path,masks_path)

# %%
valid=np.random.choice(os.listdir(images_path),200,replace=True)
val_i_list = [os.path.join(images_path,i) for i in valid]
val_m_list = [os.path.join(masks_path,i) for i in valid]
image_filenames = tf.constant(val_i_list)
masks_filenames = tf.constant(val_m_list)
valid_dataset = tf.data.Dataset.from_tensor_slices((image_filenames, masks_filenames))

# %%
test=np.random.choice(os.listdir(images_path),200,replace=True)
valid=np.random.choice(os.listdir(images_path),200,replace=True)
test_i_list = [os.path.join(images_path,i) for i in test]
test_m_list = [os.path.join(masks_path,i) for i in test]
image_filenames = tf.constant(val_i_list)
masks_filenames = tf.constant(val_m_list)
test_dataset = tf.data.Dataset.from_tensor_slices((image_filenames, masks_filenames))

# %%
train_dataset=input_data(dataset)
valid_dataset=input_data(valid_dataset)
test_dataset=input_data(test_dataset)

# %%
#show same  data 
for i in np.random.choice(list(range(1000)),4,replace=False):
    show(i,images_list,masks_list)

# %%
img_height = 96
img_width = 128
num_channels = 3

model= detector((img_height, img_width, num_channels))

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 96, 128, 3)        │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 96, 128, 32)       │             896 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 96, 128, 32)       │           9,248 │ conv2d[0][0]               │
# ...

# %%
model_history=train(model,train_dataset,EPOCHS=15)
# Out:
# Epoch 1/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 36s 943ms/step - accuracy: 0.2303 - loss: 2.6173
# Epoch 2/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 32s 935ms/step - accuracy: 0.6263 - loss: 1.2543
# Epoch 3/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 977ms/step - accuracy: 0.8183 - loss: 0.6795
# Epoch 4/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8380 - loss: 0.5656
# Epoch 5/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 958ms/step - accuracy: 0.8688 - loss: 0.4469
# Epoch 6/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 962ms/step - accuracy: 0.8855 - loss: 0.3870
# Epoch 7/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 961ms/step - accuracy: 0.8877 - loss: 0.3722
# Epoch 8/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9050 - loss: 0.3136
# Epoch 9/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 990ms/step - accuracy: 0.9125 - loss: 0.2895
# Epoch 10/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 997ms/step - accuracy: 0.9216 - loss: 0.2613
# Epoch 11/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 995ms/step - accuracy: 0.9296 - loss: 0.2361
# ...

# %%
plt.plot(model_history.history["accuracy"])

# %%
val_loss, val_accuracy= model.evaluate(valid_dataset)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 302ms/step - accuracy: 0.9430 - loss: 0.1904

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 275ms/step - accuracy: 0.9480 - loss: 0.1735

# %%
train_loss,train_accuracy=model.evaluate(train_dataset)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step - accuracy: 0.9481 - loss: 0.1738

# %%
model.save(r"D:\project zone\intelligent_navigation\my_model\navigator.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
detector =load_model(r"D:\project zone\intelligent_navigation\my_model\navigator.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
show_predictions(train_dataset,detector, 6)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step

# %%
#the end of story
